# %% [markdown]
# # **AQI Forecasting System (Air Quality Index Predictor)**
#
# ---
#
# ## **Executive Summary**
#
# This project focuses on building an end-to-end time-series forecasting system to predict the **Air Quality Index (AQI)** for the next 72 hours (3 days). Unlike standard regression problems, AQI forecasting requires strict temporal awareness, where predictions must rely exclusively on past observations to avoid data leakage.
#
# The system integrates environmental data, including pollutant concentrations (PM2.5, PM10, NO₂, CO, O₃) and weather variables such as temperature, humidity, and wind speed. These features capture the dynamic interactions that influence air quality over time.
#
# A structured workflow is followed, including time-series exploratory analysis, feature engineering (lag features, rolling statistics, and calendar variables), and model development using both linear and tree-based algorithms. The system ensures proper temporal validation using time-aware splitting techniques and supports multi-step forecasting using a recursive approach.
#
# The final solution is designed with production considerations, including automated data pipelines, feature storage, model versioning, and API-based deployment. It enables applications such as pollution monitoring, public health alerts, and environmental decision-making.
#
# ---
#
# ## **1. Problem Definition**
#
# ### Objective
# Predict future AQI values based on historical environmental data.
#
# ### Target Variable
# - PM2.5 (continuous numerical value)
#
# ### Forecast Horizon
# - Next 72 hours (3 days ahead)
#
# ### Prediction Type
# - Multi-step time-series forecasting
#
# ### Forecasting Strategy
# - Recursive forecasting:
#   - Predict next step → feed prediction back → predict further
#
# ---
#
# ## **2. Business Context**
#
# Air pollution poses significant risks to public health and urban sustainability. Accurate AQI forecasting supports:
#
# - Public health advisories
# - Outdoor activity planning
# - Government pollution control strategies
# - Environmental monitoring systems
#
# ---
#
# ## **3. ML Formulation**
#
# ### A) Forecasting → Regression Problem
# Predict AQI values (continuous) using historical data and external features.
#
# ### B) Time-Series Constraints
#
# Unlike traditional ML:
#
# - Data must be processed sequentially
# - Future data must NEVER influence past predictions
# - Validation must respect temporal ordering
#
# ---
#
# ## **4. Critical Time-Series Considerations**
#
# ### Temporal Dependency
# AQI depends on past pollution levels and weather conditions.
#
# ### Data Leakage (Critical Risk)
# Using future information during training leads to unrealistic performance.
#
# Example of leakage:
# - Using AQI(t+1) to predict AQI(t)
#
# ### Why Random Train-Test Split is Incorrect
# - Random splitting mixes past and future data
# - Causes leakage and inflated performance
#
# ### Correct Approach
# - Time-based split
# - Train on past → test on future
#
# ---
#
# ## **5. Methodology Overview**
#
# The project follows a production-oriented workflow:
#
# 1. Data Collection
#    - Fetch real-time and historical data from APIs
#
# 2. Feature Engineering
#    - Lag features (past AQI values)
#    - Rolling statistics (mean, std)
#    - Time-based features (hour, day, month)
#
# 3. Model Development
#    - Train regression models (Linear, Tree-based)
#
# 4. Temporal Validation
#    - Use time-aware validation (e.g., TimeSeriesSplit)
#
# 5. Multi-Step Forecasting
#    - Generate predictions for the next 72 hours
#
# 6. Backtesting
#    - Evaluate model performance over rolling time windows
#
# 7. Deployment Preparation
#    - Build pipelines for automation and serving
#
# ---
#
# ## **6. Input Features**
#
# ### Pollution Features
# - PM2.5, PM10
# - NO₂, CO, O₃
#
# ### Weather Features
# - Temperature
# - Humidity
# - Wind speed
#
# ### Engineered Features (to be created)
# - Lag features (AQI history)
# - Rolling statistics
# - Time-based features
#
# ---
#
# ## **7. Success Metrics**
#
# ### Primary Metric
# - **MAE (Mean Absolute Error)**
#   Measures average prediction error in AQI units
#
# ### Secondary Metrics
# - **RMSE (Root Mean Squared Error)**
# - **R² Score**
#
# ### Evaluation Strategy
# - Time-based validation
# - Backtesting across multiple periods
# - Stability across different pollution conditions
#
# ---
#
# ## **8. Final Output**
#
# The system produces:
#
# - AQI forecast for next 72 hours
# - Evaluation metrics (MAE, RMSE, R²)
# - Historical vs predicted comparison
# - AQI category labels (Good, Moderate, Unhealthy)
#
# ---
#
# ## **9. Project Goal**
#
# To develop a production-ready AQI forecasting system that accurately predicts short-term air quality using time-aware machine learning techniques, enabling better public health awareness and environmental decision-making.
#
# ---
#
# ## **10. Dataset Description**
#
# Data is collected from external APIs such as AQICN or OpenWeather.
#
# ### Key Characteristics
# - Granularity: Hourly or daily observations
# - Source: Environmental APIs
# - Time span: Historical + real-time streaming
#
# ### Features
# - datetime
# - aqi (target)
# - pm2_5, pm10
# - no2, co, o3
# - temperature
# - humidity
# - wind_speed
#
# ---

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ## Data Acquisition

# %%
res = requests.get("http://api.waqi.info/feed/karachi/?token=846fd19da16057b2b05f49f426d993bf082d4db3")
data = res.json()

# %%
data
# Out:
# {'status': 'ok',
#  'data': {'aqi': 161,
#   'idx': 11790,
#   'attributions': [{'url': 'https://pk.usembassy.gov/',
#     'name': 'Pakistan Air Quality Monitor - US EPA',
#     'logo': 'US-StateDepartment.png'},
#    {'url': 'https://waqi.info/', 'name': 'World Air Quality Index Project'}],
#   'city': {'geo': [24.8415, 67.0091],
#    'name': 'Karachi US Consulate, Pakistan',
#    'url': 'https://aqicn.org/city/pakistan/karachi/us-consulate',
#    'location': ''},
#   'dominentpol': 'pm25',
#   'iaqi': {'dew': {'v': -19},
#    'h': {'v': 3},
#    'p': {'v': 1016},
#    'pm25': {'v': 161},
#    't': {'v': 31},
#    'w': {'v': 5.1}},
#   'time': {'s': '2025-03-04 16:00:00',
#    'tz': '+05:00',
#    'v': 1741104000,
#    'iso': '2025-03-04T16:00:00+05:00'},
#   'forecast': {'daily': {'o3': [{'avg': 15,
#       'day': '2025-03-02',
#       'max': 48,
#       'min': 6},
#      {'avg': 19, 'day': '2025-03-03', 'max': 23, 'min': 17},
# ...

# %% [markdown]
# This API response is a current station-level AQI snapshot plus short pollutant forecasts, wrapped in a nested JSON structure.

# %% [markdown]
# Since the API only gives us the current AQI, we will now import an AQI dataset downloaded from kaggle for model training

# %%
df = pd.read_excel('./data/PRSA_Data_Aotizhongxin_20130301-20170228.xlsx')
df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df.drop('No', axis=1, inplace=True)

# %%
df.describe()
# Out:
#                year         month           day          hour         PM2.5  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  34139.000000
# mean    2014.662560      6.522930     15.729637     11.500000     82.773611
# std        1.177213      3.448752      8.800218      6.922285     82.135694
# min     2013.000000      1.000000      1.000000      0.000000      3.000000
# 25%     2014.000000      4.000000      8.000000      5.750000     22.000000
# 50%     2015.000000      7.000000     16.000000     11.500000     58.000000
# 75%     2016.000000     10.000000     23.000000     17.250000    114.000000
# max     2017.000000     12.000000     31.000000     23.000000    898.000000
#
#                PM10           SO2           NO2            CO            O3  \
# count  34346.000000  34129.000000  34041.000000  33288.000000  33345.000000
# mean     110.060391     17.375901     59.305833   1262.945145     56.353358
# ...

# %% [markdown]
# PM2.5 is selected as the target variable as it is the dominant pollutant influencing AQI.
#
# While AQI depends on multiple pollutants, PM2.5 is used as a proxy due to:
# - its strong correlation with AQI
# - its availability in both dataset and API
#
# Other pollutants are excluded from the model as they are not consistently available in real-time API data.
#
# The model will therefore learn to predict PM2.5 using past values and weather-related features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     35064 non-null  int64
#  1   month    35064 non-null  int64
#  2   day      35064 non-null  int64
#  3   hour     35064 non-null  int64
#  4   PM2.5    34139 non-null  float64
#  5   PM10     34346 non-null  float64
#  6   SO2      34129 non-null  float64
#  7   NO2      34041 non-null  float64
#  8   CO       33288 non-null  float64
#  9   O3       33345 non-null  float64
#  10  TEMP     35044 non-null  float64
#  11  PRES     35044 non-null  float64
#  12  DEWP     35044 non-null  float64
#  13  RAIN     35044 non-null  float64
#  14  wd       34983 non-null  object
#  15  WSPM     35050 non-null  float64
#  16  station  35064 non-null  object
# dtypes: float64(11), int64(4), object(2)
# memory usage: 4.5+ MB

# %%
df.isna().sum()
# Out:
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# Merging year, month, day, hour into one datetime field

# %%
df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour']])

# %%
cols = ['datetime'] + [col for col in df.columns if col != 'datetime']
df = df[cols]
df = df.sort_values(by='datetime')
df.head()
# Out:
#              datetime  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO  \
# 0 2013-03-01 00:00:00  2013      3    1     0    4.0   4.0   4.0   7.0  300.0
# 1 2013-03-01 01:00:00  2013      3    1     1    8.0   8.0   4.0   7.0  300.0
# 2 2013-03-01 02:00:00  2013      3    1     2    7.0   7.0   5.0  10.0  300.0
# 3 2013-03-01 03:00:00  2013      3    1     3    6.0   6.0  11.0  11.0  300.0
# 4 2013-03-01 04:00:00  2013      3    1     4    3.0   3.0  12.0  12.0  300.0
#
#      O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# 0  77.0  -0.7  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  77.0  -1.1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  73.0  -1.1  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  72.0  -1.4  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  72.0  -2.0  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df['station'].value_counts()
# Out:
# station
# Aotizhongxin    35064
# Name: count, dtype: int64

# %% [markdown]
# Since the station field is constant, we will drop it

# %%
df = df.drop('station', axis=1)

# %% [markdown]
# We will also drop the records where PM2.5 is missing, as that is our target feature

# %%
df = df.dropna(subset=['PM2.5'], ignore_index=True)

# %%
df.isna().sum()
# Out:
# datetime       0
# year           0
# month          0
# day            0
# hour           0
# PM2.5          0
# PM10           9
# SO2          282
# NO2          363
# CO          1115
# O3          1067
# TEMP          20
# PRES          20
# DEWP          20
# RAIN          20
# wd            81
# WSPM          14
# dtype: int64

# %% [markdown]
# For the remaining missing values we will use forward fill and backward fill. Forward fill will replace middle and end missing values, and backward fill will fill the initial missing values

# %%
df = df.ffill()
df = df.bfill()

# %%
df.isna().sum()
# Out:
# datetime    0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd          0
# WSPM        0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## EDA

# %% [markdown]
# Let us now explore the trend of PM2.5 overtime

# %%
plt.figure(figsize=(10,5))
plt.title('PM2.5 Trend over time')
sns.lineplot(data=df, x='datetime', y='PM2.5')
plt.show()

# %% [markdown]
# The PM2.5 time-series exhibits high volatility with frequent extreme spikes, indicating a non-stationary and high-variance process. The dense hourly observations result in an overcrowded visualization, masking underlying temporal patterns. This suggests the need for smoothing techniques such as rolling averages to reveal trend and seasonality, and highlights that the model must be capable of handling sudden fluctuations rather than relying solely on smooth trends.

# %% [markdown]
# Let us now observe rolling average per day

# %%
df['pm25_rolling_24'] = df['PM2.5'].rolling(window=24).mean()

# %%
plt.figure(figsize=(10,5))
plt.title('PM2.5 Rolling average trend')
sns.lineplot(data=df, x='datetime', y='pm25_rolling_24')
plt.show()

# %% [markdown]
# 24-hour averaging removes hourly noise, but the data is still quite volatile day-to-day. This means we need a larger window (like a week) to see clearer trends.

# %% [markdown]
# Let us observe a 7 day rolling average

# %%
df['pm25_rolling_168'] = df['PM2.5'].rolling(window=168).mean()

# %%
plt.figure(figsize=(10,5))
plt.title('PM2.5 Weekly Rolling average trend')
sns.lineplot(data=df, x='datetime', y='pm25_rolling_168')
plt.show()

# %% [markdown]
# After smoothing, PM2.5 shows a baseline around 50–100 with occasional spikes above 200. There are periods of sustained higher pollution, suggesting seasonal patterns.

# %% [markdown]
# Now we will observe the average PM2.5 per hour of the day

# %%
hourly_pattern = df.groupby('hour')['PM2.5'].mean().reset_index()

# %%
plt.figure(figsize=(10,5))
plt.title('Average PM2.5 by hour')
sns.barplot(data=hourly_pattern, x='hour', y='PM2.5')
plt.show()

# %% [markdown]
# PM2.5 levels are highest during late night and evening hours, and lowest during midday. This suggests a clear daily cycle where pollution accumulates at night and disperses during the day.

# %% [markdown]
# Now we will observe average PM2.5 by month

# %%
monthly_pattern = df.groupby('month')['PM2.5'].mean().reset_index()

# %%
plt.figure(figsize=(10,5))
plt.title('Average PM2.5 by month')
sns.barplot(data=monthly_pattern, x='month', y='PM2.5')
plt.show()

# %% [markdown]
# PM2.5 levels are highest in winter months (Nov–Feb) and lowest in summer (Jun–Aug). Pollution decreases from spring into summer and rises again in fall, showing strong seasonal patterns.

# %%
yearly_pattern = df.groupby('year')['PM2.5'].mean().reset_index()

# %%
plt.figure(figsize=(10,5))
plt.title('Average PM2.5 by year')
sns.barplot(data=yearly_pattern, x='year', y='PM2.5')
plt.show()

# %% [markdown]
# Even though PM2.5 varies across years, the pattern is not consistent or repeating. Since year does not represent a cyclical or generalizable pattern, it is better to exclude it from the model.

# %% [markdown]
# Now let us observe correlations between features

# %%
df.corr(numeric_only=True)['PM2.5'].sort_values(ascending=False)
# Out:
# PM2.5               1.000000
# PM10                0.876796
# CO                  0.784403
# pm25_rolling_24     0.753350
# NO2                 0.682179
# SO2                 0.481636
# pm25_rolling_168    0.294948
# DEWP                0.120309
# month               0.025505
# day                 0.007920
# PRES               -0.005879
# hour               -0.010388
# RAIN               -0.014003
# year               -0.030612
# TEMP               -0.129145
# O3                 -0.164759
# WSPM               -0.278739
# Name: PM2.5, dtype: float64

# %% [markdown]
# PM2.5 shows strong correlation with other pollutants such as PM10, CO, and NO2, indicating shared environmental drivers. Lag features also show high correlation, confirming temporal dependency. Weather variables like wind speed and temperature have weaker linear relationships but may still contribute through non-linear effects.

# %% [markdown]
# We will now examine the relationship between PM2.5 and key weather variables such as temperature and wind speed. Although these features show weak linear correlation, they may still influence pollution through non-linear relationships, which we aim to explore through visualization

# %%
plt.title('PM2.5 vs TEMP')
sns.scatterplot(data=df, x='TEMP', y='PM2.5')
plt.show()

# %%
plt.title('PM2.5 vs WSPM')
sns.scatterplot(data=df, x='WSPM', y='PM2.5')
plt.show()

# %% [markdown]
# Although linear correlation is weak, the scatter plots reveal non-linear relationships. Wind speed shows a clear inverse pattern, where higher wind reduces pollution levels. Temperature also shows a general trend where higher temperatures are associated with lower PM2.5, though the relationship is more dispersed

# %% [markdown]
# ---

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Since PM2.5 is a time-dependent variable, feature engineering must provide the model with information about recent pollution history, short-term trends, and recurring temporal cycles. Based on EDA, lag features are created to capture temporal dependency, rolling features are created to summarize recent trends and volatility, and calendar features are included to represent daily and seasonal patterns.

# %%
df['lag_1'] = df['PM2.5'].shift(1)

# %% [markdown]
# lag_1 is created to give the model the PM2.5 value from the previous hour, since current pollution levels are strongly influenced by the most recent observation.

# %%
df['lag_2'] = df['PM2.5'].shift(2)
df['lag_3'] = df['PM2.5'].shift(3)

# %% [markdown]
# lag_2 and lag_3 are created to capture short-term movement in PM2.5, helping the model detect whether pollution is increasing or decreasing over recent hours.

# %%
df['lag_24'] = df['PM2.5'].shift(24)

# %% [markdown]
# lag_24 is created to capture daily seasonality, since PM2.5 at a given hour is likely to be influenced by pollution levels at the same hour on the previous day.

# %%
df['lag_168'] = df['PM2.5'].shift(168)

# %% [markdown]
# lag_168 is created to capture longer-term weekly patterns, allowing the model to compare current conditions with the same time in the previous week.

# %% [markdown]
# Let us now check whether we can find a meaningful pattern by observing day of the week

# %%
df['day_of_week'] = df['datetime'].dt.dayofweek

weekly_pattern = df.groupby('day_of_week')['PM2.5'].mean().reset_index()


plt.title('Average PM2.5 by Day of the Week')
sns.barplot(data=weekly_pattern, x='day_of_week', y='PM2.5')
plt.show()

# %% [markdown]
# Although day_of_week is a cyclical feature, EDA shows minimal variation in PM2.5 across different days, suggesting weak predictive value. Therefore, it is excluded to simplify the model and focus on more impactful features

# %%
df = df.drop('day_of_week', axis=1)

# %% [markdown]
# As mentioned before we will drop all other pollutants as our api does not return them so we will exclude them from our data

# %%
df = df.drop(['PM10', 'SO2', 'NO2', 'CO', 'O3'], axis=1)

# %% [markdown]
# The year feature will be dropped as it did not show us a significant enough pattern

# %%
df = df.drop('year', axis=1)

# %% [markdown]
# The datetime feature will be dropped as we already have derived features from it, and datetime itself would hold no meaning for model training

# %%
df = df.drop('datetime', axis=1)

# %% [markdown]
# We will also drop wd feature, as wind direction is also not returned by our API

# %%
df = df.drop('wd', axis=1)

# %% [markdown]
# Although the day of the month follows a numerical cycle, it does not represent a meaningful or consistent environmental pattern affecting PM2.5. Therefore, it is excluded to avoid introducing noise into the model.

# %%
df = df.drop('day', axis=1)

# %% [markdown]
# We will also drop all rows with missing values as a result of lag and rolling features

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['month', 'hour', 'PM2.5', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM',
#        'pm25_rolling_24', 'pm25_rolling_168', 'lag_1', 'lag_2', 'lag_3',
#        'lag_24', 'lag_168'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## Model Building

# %%
X = df.drop('PM2.5', axis=1)
y = df['PM2.5']

# %% [markdown]
# For splitting training and testing data we will use a Time Series Split

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
lr_pipe = Pipeline(
    steps=[
        ('preprocessor', StandardScaler()),
        ('model', LinearRegression())
    ]
)

# %%
def train_model(pipe):
    mae_scores = []
    rmse_scores = []
    for train_index, test_index in tscv.split(X):
        X_train = X.iloc[train_index]
        X_test = X.iloc[test_index]
        
        y_train = y.iloc[train_index]
        y_test = y.iloc[test_index]
    
        pipe.fit(X_train, y_train)
        y_pred = pipe.predict(X_test)
    
        mae_scores.append(mean_absolute_error(y_test, y_pred))
        rmse_scores.append(root_mean_squared_error(y_test, y_pred))

    return {
        'mae_scores': mae_scores,
        'rmse_scores': rmse_scores
    }

# %%
lr_results = train_model(reg_pipe)
lr_mae_scores = results['mae_scores']
lr_rmse_scores = results['rmse_scores']

# %%
print(lr_mae_scores)
print(lr_rmse_scores)
print(f"Average MAE: {sum(lr_mae_scores)/len(lr_mae_scores)}")
print(f"Average MAE: {sum(lr_rmse_scores)/len(lr_rmse_scores)}")
# Out:
# [12.945142571046631, 10.359583467903121, 9.100093718250365, 10.98094871083794, 10.648231352602988]
# [22.926667498209717, 18.4882507856314, 17.369189540750938, 22.732553504374728, 19.14952454026006]
# Average MAE: 10.806799964128208
# Average MAE: 20.133237173845366

# %% [markdown]
# The baseline Linear Regression model achieved stable performance across all time-based folds, indicating that the engineered lag, rolling, and weather features capture meaningful predictive signal. However, RMSE is notably higher than MAE, suggesting that the model struggles more on extreme pollution spikes than on typical observations.
#
# This strong performance is largely driven by lag and rolling features, which explicitly encode past PM2.5 behavior. Since current pollution levels depend heavily on recent values, these features transform the forecasting problem into a structured autoregressive form that a linear model can learn effectively.

# %% [markdown]
# While Linear Regression has limitations in capturing non-linear relationships, the engineered lag and rolling features significantly simplify the problem structure, allowing the model to perform effectively as a baseline.

# %%
rfr_pipe = Pipeline(
    steps=[
        ('model', RandomForestRegressor(n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, random_state=42))
    ]
)

# %%
rfr_results = train_model(rfr_pipe)
rfr_mae_scores = rfr_results['mae_scores']
rfr_rmse_scores = rfr_results['rmse_scores']

# %%
print(rfr_mae_scores)
print(rfr_rmse_scores)
print(f"Average MAE: {sum(rfr_mae_scores)/len(rfr_mae_scores)}")
print(f"Average MAE: {sum(rfr_rmse_scores)/len(rfr_rmse_scores)}")
# Out:
# [13.966165318834785, 10.71801776034192, 9.241669620430745, 11.389971702146404, 10.490298341350746]
# [24.99098836464698, 19.154437237850185, 17.267608913140027, 24.529397626215935, 18.987990626041064]
# Average MAE: 11.16122454862092
# Average MAE: 20.986084553578838

# %% [markdown]
# Although Random Forest can model non-linear relationships, it did not outperform Linear Regression. This indicates that the lag and rolling features have already captured most of the temporal structure in the data. As a result, the problem becomes sufficiently structured for a linear model, and additional model complexity provides limited benefit.

# %% [markdown]
# To further explore whether more advanced non-linear models can improve performance, we will evaluate XGBoost, which often performs well on structured tabular data.

# %%
xgb_pipe = Pipeline(
    steps=[
        ('model', XGBRegressor(
            n_estimators=200,
            max_depth=6, # Learning rate scales the contribution of each new tree before adding it to the model.
            learning_rate=0.1,
            subsample=0.8, # each tree is trained on 80% of the rows, randomizes the subset of rows each tree gets
            colsample_bytree=0.8, # each tree is trained on 80% of the features, randomizes the subset of features each tree gets
            random_state=42
        ))
    ]
)

# %%
xgb_results = train_model(xgb_pipe)
xgb_mae_scores = xgb_results['mae_scores']
xgb_rmse_scores = xgb_results['rmse_scores']

# %%
print(xgb_mae_scores)
print(xgb_rmse_scores)
print(f"Average MAE: {sum(xgb_mae_scores)/len(xgb_mae_scores)}")
print(f"Average MAE: {sum(xgb_rmse_scores)/len(xgb_rmse_scores)}")
# Out:
# [16.873896048629565, 11.087750285026821, 9.120202499311144, 11.868545543345181, 10.74282758927897]
# [33.28674294029037, 19.419515999208656, 17.34533671810506, 26.40977918583835, 19.730044267025598]
# Average MAE: 11.938644393118336
# Average MAE: 23.238283822093607

# %% [markdown]
# Since the feature set contains several correlated lag and rolling variables, Ridge Regression is worth evaluating as a regularized extension of Linear Regression. This allows us to test whether coefficient shrinkage can improve generalization and reduce sensitivity to noisy fluctuations.

# %%
ridge_pipe = Pipeline(
    steps=[
        ('preprocessor', StandardScaler()),
        ('model', Ridge(alpha=1))
    ]
)

# %%
ridge_results = train_model(ridge_pipe)
ridge_mae_scores = ridge_results['mae_scores']
ridge_rmse_scores = ridge_results['rmse_scores']

# %%
print(ridge_mae_scores)
print(ridge_rmse_scores)
print(f"Average MAE: {sum(ridge_mae_scores)/len(ridge_mae_scores)}")
print(f"Average MAE: {sum(ridge_rmse_scores)/len(ridge_rmse_scores)}")
# Out:
# [12.948649848022654, 10.363374235911744, 9.100939485918254, 10.982617257622152, 10.64961787243833]
# [22.924081851641034, 18.491379470928507, 17.366823524486268, 22.733765914870112, 19.151911033083465]
# Average MAE: 10.809039739982627
# Average MAE: 20.133592359001877

# %% [markdown]
# Ridge Regression produces nearly identical performance to Linear Regression, indicating that regularization does not significantly improve model performance in this case. This suggests that the model is not heavily affected by coefficient instability or overfitting, and that the engineered features already provide a well-structured representation of the data.

# %% [markdown]
# Since Ridge Regression does not provide a meaningful improvement over Linear Regression, the simpler Linear model is selected as the final model. This choice is justified by its comparable performance and greater interpretability

# %% [markdown]
# ---

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Based on our previous section we have selected the Linear Regression model to be our final model. We will now evalute it

# %% [markdown]
# First we will observe the plot of actual target values vs predicted target values

# %%
for train_index, test_index in tscv.split(X):
    pass

X_train = X.iloc[train_index]
X_test = X.iloc[test_index]

y_train = y.iloc[train_index]
y_test = y.iloc[test_index]

lr_pipe.fit(X_train, y_train)
y_pred = lr_pipe.predict(X_test)

# %%
plt.figure(figsize=(12,8))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Actual vs Predicted PM2.5')
plt.legend()
plt.show()

# %% [markdown]
# The model closely follows the actual PM2.5 values across time, indicating strong predictive performance. However, at certain extreme peaks, the model slightly underestimates the true values, suggesting difficulty in fully capturing rare high-intensity pollution events.

# %% [markdown]
# Now let us observe the errors thrugh a Residual plot

# %%
residuals = y_test - y_pred

plt.figure(figsize=(8,4))
plt.scatter(y_pred, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %% [markdown]
# Residuals are mostly centered around zero, showing that the model performs reasonably well overall. However, noticeable errors are present across all prediction ranges, including moderate PM2.5 values. The spread of errors increases slightly as predicted values grow, indicating that the model becomes less reliable at higher pollution levels. This suggests that while the model captures general patterns well, it struggles to precisely predict both moderate fluctuations and extreme spikes.

# %% [markdown]
# Let us now observe which feature importance, to analzye which features contribute the most in model's predictions

# %%
coefficients = lr_pipe.named_steps['model'].coef_

feature_names = X.columns

coef_df = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

coef_df = coef_df.sort_values(by='Coefficient', ascending=False)
coef_df
# Out:
#              Feature  Coefficient
# 9              lag_1    87.575077
# 7    pm25_rolling_24     3.867790
# 4               DEWP     3.784136
# 1               hour     1.674390
# 13           lag_168     0.003271
# 8   pm25_rolling_168    -0.169972
# 3               PRES    -0.265668
# 0              month    -0.659390
# 11             lag_3    -0.731452
# 5               RAIN    -1.183193
# 12            lag_24    -1.369367
# 6               WSPM    -1.601000
# 2               TEMP    -4.100295
# 10             lag_2   -13.664657

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=coef_df, x='Coefficient', y='Feature')
plt.title('Feature Importance (Linear Regression Coefficients)')
plt.show()

# %% [markdown]
# The coefficient analysis shows that the lag_1 feature has an overwhelmingly dominant influence on predictions, indicating that the most recent PM2.5 value is the strongest predictor of current pollution levels. Other lag and rolling features contribute minimally, likely due to high correlation with lag_1, causing the model to rely primarily on the most recent observation. Weather-related features have very small coefficients, suggesting that their impact is secondary compared to temporal dependency. This confirms that PM2.5 behaves as a strongly autoregressive time series, where recent history drives most of the predictive power.
#
# Due to the presence of highly correlated lag and rolling features, individual coefficients may not be fully stable or directly interpretable. However, the model’s predictive performance remains consistent, indicating that the overall signal captured by these features is robust despite coefficient variability.

# %% [markdown]
# ---

# %% [markdown]
# ## Final Conclusion
#
# This project demonstrates that accurate short-term AQI forecasting can be achieved by transforming the time-series problem into a structured regression task through effective feature engineering. By incorporating lag features, rolling statistics, and calendar-based variables, the model is able to capture temporal dependencies, short-term trends, and seasonal patterns present in air pollution data.
#
# Among the evaluated models, Linear Regression performed competitively and matched or exceeded the performance of more complex models such as Random Forest and XGBoost. Further experimentation with Ridge Regression showed no meaningful improvement, indicating that the model is already stable and not significantly affected by overfitting or coefficient instability. This suggests that the predictive power of the system is driven primarily by the engineered features rather than model complexity.
#
# Model evaluation shows that predictions closely follow actual PM2.5 values, confirming that the model effectively captures overall trends and temporal behavior. However, residual analysis highlights that prediction errors increase during higher pollution levels and extreme spikes, which are inherently difficult to model due to their volatile and irregular nature.
#
# Feature importance analysis reveals that the most recent PM2.5 value (lag_1) is the dominant predictor, confirming strong temporal dependency in the data. Other lag and rolling features provide additional context but contribute less due to their high correlation with recent observations. Weather-related features, while relevant, have a comparatively smaller impact on predictions.
#
# Overall, the results highlight that for time-series forecasting problems like AQI prediction, careful feature engineering plays a more critical role than increasing model complexity. The final model provides reliable short-term forecasts and serves as a strong foundation for a production-ready system that can be extended with real-time data pipelines, automated retraining, and deployment through APIs and dashboards.
